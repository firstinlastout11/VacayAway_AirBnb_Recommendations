# %% [markdown]
# # Code to obtain data from HomeAway
# This code will scrape data from HomeAway using RESTful API calls. It will:
#
# 1. Send a POST request to https://ws.homeaway.com/oauth/token using our API Client's credentials with a Basic Auth header to obtain an `access_token` for subsequent API calls
# 2. Send GET requests to https://ws.homeaway.com/public/search to obtain information about listings in Atlanta in the form of a JSON file. **This might need to be modified to be more specific in the future.**
#     - These GET requests require dates of stays in order to obtain the average nightly price of every listing. Therefore, to be safe, these GET requests will obtain listings for the timeframe of **June 1, 2019 (2019-07-01) - June 9, 2019 (2019-07-01).**
# 3. Extract the following information from the JSON file and put it in a Pandas DataFrame:
#     - listingId
#     - priceQuote -> amount
#     - priceQuote -> averageNightly
#     - priceQuote -> fees
#     - priceQuote -> rent
#     - location -> lat
#     - location -> lng
#     - location -> city
#     - location -> state
#     - location -> country
#     - reviewCount
#     - reviewAverage
#     - bathrooms
#     - bedrooms
#     - listingUrl
#     - bookWithConfidence **(maybe??)**

# %%
# Imports
import http.client
import json
import time
import sys
import collections
import csv
import socket
import requests
import pandas as pd
import time

# %% [markdown]
# ### Send a POST request to the OAuth Server

# %%
## construct request
url = "https://ws.homeaway.com/oauth/token"

payload = ""
headers = {
    'Authorization': "Basic NzViNDgyOTktZGEyNS00YWNkLThiYjctM2EyMTJkMWVmOTljOmEyN2M1YmNlLWRhOTYtNGEwNS1hYzRmLTE3NDBkMDFiYWJjNQ==",
    'cache-control': "no-cache",
    'Postman-Token': "f60f6d42-07c7-4b8f-aaa5-f0a03d307012"
    }

## send POST request
print("| - - POST - - |")
print("Sending POST request to", url)
print("Authorization:", headers['Authorization'])
print("Postman Token:", headers['Postman-Token'])
response = requests.request("POST", url, data=payload, headers=headers)
print("| - - SUCCESS - - |")
# print(response.text)

## extract `access_token`
access_token = response.json()['access_token']
print("Access Token is", access_token)
# Out:
# | - - POST - - |
# Sending POST request to https://ws.homeaway.com/oauth/token
# Authorization: Basic NzViNDgyOTktZGEyNS00YWNkLThiYjctM2EyMTJkMWVmOTljOmEyN2M1YmNlLWRhOTYtNGEwNS1hYzRmLTE3NDBkMDFiYWJjNQ==
# Postman Token: f60f6d42-07c7-4b8f-aaa5-f0a03d307012
# | - - SUCCESS - - |
# Access Token is OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj

# %%
url = "https://ws.homeaway.com/public/search"

val_pageSize = 25
val_pageNum = 22

date_availabilityStart = "2019-07-01"
date_availabilityEnd = "2019-07-09"

querystring = {"q":"Atlanta",
               "availabilityStart": date_availabilityStart,
               "availabilityEnd":date_availabilityEnd,
               "pageSize":str(val_pageSize),
               "page":str(val_pageNum)}

payload = ""
headers = {
    'Authorization': "Bearer " + access_token,
    'cache-control': "no-cache",
    'Postman-Token': "9a32c226-9a48-417f-b062-5070f405af71"
    }

response = requests.request("GET", url, data=payload, headers=headers, params=querystring).json()

# %%
response
# Out:
# {'nextPage': 'https://ws.homeaway.com/public/search?q=Atlanta&availabilityStart=2019-07-01&availabilityEnd=2019-07-09&pageSize=25&page=23',
#  'prevPage': 'https://ws.homeaway.com/public/search?q=Atlanta&availabilityStart=2019-07-01&availabilityEnd=2019-07-09&pageSize=25&page=21',
#  'pageSize': 25,
#  'pageCount': 81,
#  'page': 22,
#  'size': 2009,
#  'refinements': [],
#  'entries': [{'listingId': '7415150',
#    'listingSource': 'homeaway_us',
#    'headline': 'ATL.CV 1116 - Deluxe Apartment One Bedroom 4 pax CV 1116',
#    'description': 'Stake your claim to a life beyond the view. 1stHomeRent connects you to all of the best shopping, dining and activity of Old Fourth Ward, Inman Park and the Atlanta Beltline while allowing you the savings to enjoy them. Our apartment is designed w...',
#    'accommodations': '1 BR, 1.0BA, Sleeps 4',
#    'minStayRange': {'minStayHigh': None, 'minStayLow': None},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/75ab9eee-bcf2-4103-9142-e91f46921524.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/75ab9eee-bcf2-4103-9142-e91f46921524.1.1',
#     'width': 133},
#    'priceQuote': {'amount': 1726.2,
#     'averageNightly': 215.78,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 1726.2,
#     'tax': None},
#    'priceRanges': [],
#    'location': {'lat': 33.760714,
#     'lng': -84.374001,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 0,
#    'reviewAverage': 0.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=7415150',
#    'bathrooms': 1.0,
#    'bedrooms': 1,
#    'listingUrl': 'https://www.homeaway.com/vacation-rental/p7415150?uni_id=6791688'},
#   {'listingId': '7415154',
#    'listingSource': 'homeaway_us',
#    'headline': 'ATL.CV 1414 - Deluxe Apartment One Bedroom 4 pax CV 1414',
#    'description': 'Stake your claim to a life beyond the view. 1stHomeRent connects you to all of the best shopping, dining and activity of Old Fourth Ward, Inman Park and the Atlanta Beltline while allowing you the savings to enjoy them. Our apartment is designed w...',
#    'accommodations': '1 BR, 1.0BA, Sleeps 4',
#    'minStayRange': {'minStayHigh': None, 'minStayLow': None},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/51711ef9-75ed-4011-89f7-48a27228579d.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/51711ef9-75ed-4011-89f7-48a27228579d.1.1',
#     'width': 133},
#    'priceQuote': {'amount': 1726.2,
#     'averageNightly': 215.78,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 1726.2,
#     'tax': None},
#    'priceRanges': [],
#    'location': {'lat': 33.760714,
#     'lng': -84.374001,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 0,
#    'reviewAverage': 0.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=7415154',
#    'bathrooms': 1.0,
#    'bedrooms': 1,
#    'listingUrl': 'https://www.homeaway.com/vacation-rental/p7415154?uni_id=6791692'},
#   {'listingId': '7415140',
#    'listingSource': 'homeaway_us',
#    'headline': 'ATL.CV 1139 -  Deluxe Apartment One Bedroom 4 pax CV 1139',
#    'description': 'Stake your claim to a life beyond the view. 1stHomeRent connects you to all of the best shopping, dining and activity of Old Fourth Ward, Inman Park and the Atlanta Beltline while allowing you the savings to enjoy them. Our apartment is designed w...',
#    'accommodations': '1 BR, 1.0BA, Sleeps 4',
#    'minStayRange': {'minStayHigh': None, 'minStayLow': None},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/0c83b5ac-2de7-4268-aaeb-d34fdcda49d3.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/0c83b5ac-2de7-4268-aaeb-d34fdcda49d3.1.1',
#     'width': 133},
#    'priceQuote': {'amount': 1726.2,
#     'averageNightly': 215.78,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 1726.2,
#     'tax': None},
#    'priceRanges': [],
#    'location': {'lat': 33.760714,
#     'lng': -84.374001,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 0,
#    'reviewAverage': 0.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=7415140',
#    'bathrooms': 1.0,
#    'bedrooms': 1,
#    'listingUrl': 'https://www.homeaway.com/vacation-rental/p7415140?uni_id=6791678'},
#   {'listingId': '7415151',
#    'listingSource': 'homeaway_us',
#    'headline': 'ATL.CV 1164 - Deluxe Apartment One Bedroom 4 pax CV 1164',
#    'description': 'Stake your claim to a life beyond the view. 1stHomeRent connects you to all of the best shopping, dining, and activity of Old Fourth Ward, Inman Park and the Atlanta Beltline while allowing you the savings to enjoy them. Our apartment is designed ...',
#    'accommodations': '1 BR, 1.0BA, Sleeps 4',
#    'minStayRange': {'minStayHigh': None, 'minStayLow': None},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/df3cc32b-75cb-4365-9007-da750af29a42.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/df3cc32b-75cb-4365-9007-da750af29a42.1.1',
#     'width': 133},
#    'priceQuote': {'amount': 1726.2,
#     'averageNightly': 215.78,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 1726.2,
#     'tax': None},
#    'priceRanges': [],
#    'location': {'lat': 33.760714,
#     'lng': -84.374001,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 0,
#    'reviewAverage': 0.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=7415151',
#    'bathrooms': 1.0,
#    'bedrooms': 1,
#    'listingUrl': 'https://www.homeaway.com/vacation-rental/p7415151?uni_id=6791689'},
#   {'listingId': '7415147',
#    'listingSource': 'homeaway_us',
#    'headline': 'ATL.CV 1117 - Deluxe Apartment One Bedroom 4 pax CV 1117',
#    'description': 'Stake your claim to a life beyond the view. 1stHomeRent connects you to all of the best shopping, dining and activity of Old Fourth Ward, Inman Park and the Atlanta Beltline while allowing you the savings to enjoy them. Our apartment is designed w...',
#    'accommodations': '1 BR, 1.0BA, Sleeps 4',
#    'minStayRange': {'minStayHigh': None, 'minStayLow': None},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/8143623f-dcd7-4c59-bf9d-40dd49d4e50c.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/8143623f-dcd7-4c59-bf9d-40dd49d4e50c.1.1',
#     'width': 133},
#    'priceQuote': {'amount': 1726.2,
#     'averageNightly': 215.78,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 1726.2,
#     'tax': None},
#    'priceRanges': [],
#    'location': {'lat': 33.760714,
#     'lng': -84.374001,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 0,
#    'reviewAverage': 0.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=7415147',
#    'bathrooms': 1.0,
#    'bedrooms': 1,
#    'listingUrl': 'https://www.homeaway.com/vacation-rental/p7415147?uni_id=6791685'},
#   {'listingId': '7415136',
#    'listingSource': 'homeaway_us',
#    'headline': 'ATL.CV 1402 - Deluxe Apartment Two Bedroom 6 pax CV 1402',
#    'description': 'Stake your claim to a life beyond the view. 1stHomeRent connects you to all of the best shopping, dining and activity of Old Fourth Ward, Inman Park and the Atlanta Beltline while allowing you the savings to enjoy them. Our apartment is designed w...',
#    'accommodations': '2 BR, 2.0BA, Sleeps 6',
#    'minStayRange': {'minStayHigh': None, 'minStayLow': None},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/513d73f7-3b58-415e-bc9c-d1b7fb5ec834.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/513d73f7-3b58-415e-bc9c-d1b7fb5ec834.1.1',
#     'width': 133},
#    'priceQuote': {'amount': 2301.02,
#     'averageNightly': 287.63,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 2301.02,
#     'tax': None},
#    'priceRanges': [],
#    'location': {'lat': 33.760714,
#     'lng': -84.374001,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 0,
#    'reviewAverage': 0.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=7415136',
#    'bathrooms': 2.0,
#    'bedrooms': 2,
#    'listingUrl': 'https://www.homeaway.com/vacation-rental/p7415136?uni_id=6791674'},
#   {'listingId': '7415146',
#    'listingSource': 'homeaway_us',
#    'headline': 'ATL.CV 1064 - Deluxe Apartment One Bedroom 4 pax CV 1064',
#    'description': 'Stake your claim to a life beyond the view. 1stHomeRent connects you to all of the best shopping, dining, and activity of Old Fourth Ward, Inman Park, and the Atlanta Beltline while allowing you the savings to enjoy them. Our apartment is designed...',
#    'accommodations': '1 BR, 1.0BA, Sleeps 4',
#    'minStayRange': {'minStayHigh': None, 'minStayLow': None},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/cf3540ae-db26-4024-b9cc-f8acfbe2b76c.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/cf3540ae-db26-4024-b9cc-f8acfbe2b76c.1.1',
#     'width': 133},
#    'priceQuote': {'amount': 1726.2,
#     'averageNightly': 215.78,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 1726.2,
#     'tax': None},
#    'priceRanges': [],
#    'location': {'lat': 33.760714,
#     'lng': -84.374001,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 0,
#    'reviewAverage': 0.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=7415146',
#    'bathrooms': 1.0,
#    'bedrooms': 1,
#    'listingUrl': 'https://www.homeaway.com/vacation-rental/p7415146?uni_id=6791684'},
#   {'listingId': '7415145',
#    'listingSource': 'homeaway_us',
#    'headline': 'ATL.CV 1229 - Deluxe Apartment One Bedroom 4 pax CV 1229',
#    'description': 'Stake your claim to a life beyond the view. 1stHomeRent connects you to all of the best shopping, dining, and activity of Old Fourth Ward, Inman Park and the Atlanta Beltline while allowing you the savings to enjoy them. Our apartment is designed ...',
#    'accommodations': '1 BR, 1.0BA, Sleeps 4',
#    'minStayRange': {'minStayHigh': None, 'minStayLow': None},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/94e32003-54eb-44d5-a0fe-12b78af3405c.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/94e32003-54eb-44d5-a0fe-12b78af3405c.1.1',
#     'width': 133},
#    'priceQuote': {'amount': 1726.2,
#     'averageNightly': 215.78,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 1726.2,
#     'tax': None},
#    'priceRanges': [],
#    'location': {'lat': 33.760714,
#     'lng': -84.374001,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 0,
#    'reviewAverage': 0.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=7415145',
#    'bathrooms': 1.0,
#    'bedrooms': 1,
#    'listingUrl': 'https://www.homeaway.com/vacation-rental/p7415145?uni_id=6791683'},
#   {'listingId': '7415149',
#    'listingSource': 'homeaway_us',
#    'headline': 'ATL.CV 1214 - Deluxe Apartment One Bedroom 4 pax CV 1214',
#    'description': 'Stake your claim to a life beyond the view. 1stHomeRent connects you to all of the best shopping, dining and activity of Old Fourth Ward, Inman Park and the Atlanta Beltline while allowing you the savings to enjoy them. Our apartment is designed w...',
#    'accommodations': '1 BR, 1.0BA, Sleeps 4',
#    'minStayRange': {'minStayHigh': None, 'minStayLow': None},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/9e1a8290-f3aa-4f1e-b6d9-a1bc30e76659.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/9e1a8290-f3aa-4f1e-b6d9-a1bc30e76659.1.1',
#     'width': 133},
#    'priceQuote': {'amount': 1726.2,
#     'averageNightly': 215.78,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 1726.2,
#     'tax': None},
#    'priceRanges': [],
#    'location': {'lat': 33.760714,
#     'lng': -84.374001,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 0,
#    'reviewAverage': 0.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=7415149',
#    'bathrooms': 1.0,
#    'bedrooms': 1,
#    'listingUrl': 'https://www.homeaway.com/vacation-rental/p7415149?uni_id=6791687'},
#   {'listingId': '7415144',
#    'listingSource': 'homeaway_us',
#    'headline': 'ATL.CV 1222 - Deluxe Apartment One Bedroom 4 pax CV 1222',
#    'description': 'Stake your claim to a life beyond the view. 1stHomeRent connects you to all of the best shopping, dining and activity of Old Fourth Ward, Inman Park and the Atlanta Beltline while allowing you the savings to enjoy them. Our apartment is designed w...',
#    'accommodations': '1 BR, 1.0BA, Sleeps 4',
#    'minStayRange': {'minStayHigh': None, 'minStayLow': None},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/d55de54d-70b7-4841-a73e-0030243c806e.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/d55de54d-70b7-4841-a73e-0030243c806e.1.1',
#     'width': 133},
#    'priceQuote': {'amount': 1726.2,
#     'averageNightly': 215.78,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 1726.2,
#     'tax': None},
#    'priceRanges': [],
#    'location': {'lat': 33.76098,
#     'lng': -84.3738,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 0,
#    'reviewAverage': 0.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=7415144',
#    'bathrooms': 1.0,
#    'bedrooms': 1,
#    'listingUrl': 'https://www.homeaway.com/vacation-rental/p7415144?uni_id=6791682'},
#   {'listingId': '7415139',
#    'listingSource': 'homeaway_us',
#    'headline': 'ATL.CV 1239- Deluxe Apartment One Bedroom 4 pax CV 1239',
#    'description': 'Stake your claim to a life beyond the view. 1stHomeRent connects you to all of the best shopping, dining and activity of Old Fourth Ward, Inman Park and the Atlanta Beltline while allowing you the savings to enjoy them. Our apartment is designed w...',
#    'accommodations': '1 BR, 1.0BA, Sleeps 4',
#    'minStayRange': {'minStayHigh': None, 'minStayLow': None},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/389a0710-a110-4542-9f06-33eca6693c20.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/389a0710-a110-4542-9f06-33eca6693c20.1.1',
#     'width': 133},
#    'priceQuote': {'amount': 1726.2,
#     'averageNightly': 215.78,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 1726.2,
#     'tax': None},
#    'priceRanges': [],
#    'location': {'lat': 33.760714,
#     'lng': -84.374001,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 0,
#    'reviewAverage': 0.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=7415139',
#    'bathrooms': 1.0,
#    'bedrooms': 1,
#    'listingUrl': 'https://www.homeaway.com/vacation-rental/p7415139?uni_id=6791677'},
#   {'listingId': '7409043',
#    'listingSource': 'homeaway_us',
#    'headline': 'The Welch (Two miles from Downtown and Tourist Attractions)',
#    'description': 'Gut Rehab house located in a community currently undergoing revitalization within 2 miles of Downtown Atlanta . The house is nicely constructed with an  open air layout plan of the living , dining room and kitchen. The new modern kitchen comes wit...',
#    'accommodations': '4 BR, 2.0BA, Sleeps 14',
#    'minStayRange': {'minStayHigh': None, 'minStayLow': None},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/5d766387-21bc-4a24-ac04-a025f695ff0c.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/5d766387-21bc-4a24-ac04-a025f695ff0c.1.1',
#     'width': 133},
#    'priceQuote': {'amount': 1958.92,
#     'averageNightly': 244.87,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 1958.92,
#     'tax': None},
#    'priceRanges': [],
#    'location': {'lat': 33.7326594,
#     'lng': -84.4044832,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 0,
#    'reviewAverage': 0.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=7409043',
#    'bathrooms': 2.0,
#    'bedrooms': 4,
#    'listingUrl': 'https://www.homeaway.com/vacation-rental/p7409043?uni_id=6784863'},
#   {'listingId': '4870221',
#    'listingSource': 'homeaway_us',
#    'headline': 'Stylish Atlanta Townhome',
#    'description': 'This cozy 2 bedroom, inside a stylishly-designed 2-story townhouse w/ private patio, invites relaxation and offers modern comfort. With a private bathroom in each bedroom, the bedroom arrangement allows for the utmost privacy. Generous  living spa...',
#    'accommodations': '2 BR, 2.0BA, 1HF BA, Sleeps 2',
#    'minStayRange': {'minStayHigh': 1, 'minStayLow': 1},
#    'thumbnail': {'height': 82,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/641d3afc-f2fb-4f32-82c7-4300718463c0.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/641d3afc-f2fb-4f32-82c7-4300718463c0.1.1',
#     'width': 133},
#    'priceQuote': {'amount': 1200.0,
#     'averageNightly': 150.0,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 1200.0,
#     'tax': None},
#    'priceRanges': [{'currencyUnits': 'USD',
#      'from': 160.0,
#      'periodType': 'NIGHTLY-WEEKDAY',
#      'to': 160.0}],
#    'location': {'lat': 33.73043569,
#     'lng': -84.50694149,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 0,
#    'reviewAverage': 0.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=4870221',
#    'bathrooms': 2.0,
#    'bedrooms': 2,
#    'listingUrl': 'https://www.homeaway.com/vacation-rental/p4870221?uni_id=5895576'},
#   {'listingId': 'v1581243',
#    'listingSource': 'vrbo',
#    'headline': 'ATL Hotspot/2BR/2.5BA/Free Wifi/15 mins to Airport & Downtown',
#    'description': 'Welcome to the ATL Hotspot! Location, Location, Location!  3-5 minute drive to all interstates.  15 mins to the airport! 15 mins to downtown! The neighborhood is considered Cascade. \nEnjoy flexible check-in times, the privacy of garage, & Free WiF...',
#    'accommodations': '2 BR, 2.0BA, 1HF BA, Sleeps 5',
#    'minStayRange': {'minStayHigh': None, 'minStayLow': None},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/850f8f58-d2b3-4c9a-bdde-7d6c677a9d42.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/850f8f58-d2b3-4c9a-bdde-7d6c677a9d42.1.1',
#     'width': 75},
#    'priceQuote': {'amount': 680.0,
#     'averageNightly': 85.0,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 680.0,
#     'tax': None},
#    'priceRanges': [],
#    'location': {'lat': 33.70143466,
#     'lng': -84.49602482,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 0,
#    'reviewAverage': 0.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=v1581243',
#    'bathrooms': 2.0,
#    'bedrooms': 2,
#    'listingUrl': 'https://www.vrbo.com/1581243?unitId=2142501'},
#   {'listingId': '4560074',
#    'listingSource': 'homeaway_us',
#    'headline': 'BUCKHEAD EAST PACES 1 BEDROOM LUXURY APARTMENT WITH POOL VIEW',
#    'description': 'HOMEAWAY and VRBO Guest - Our response score listed is incorrect. We responded to all inquired quickly, if not within 1- Hour.  \n\nWhen searching for luxury apartments in Buckhead, you want to find a home with the best amenities designed for modern...',
#    'accommodations': '1 BR, 1.0BA, Sleeps 2',
#    'minStayRange': {'minStayHigh': 3, 'minStayLow': 3},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/c9aa6ca4-9cbe-42b2-a400-e17ea09b968a.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/c9aa6ca4-9cbe-42b2-a400-e17ea09b968a.1.1',
#     'width': 134},
#    'priceQuote': {'amount': 1060.0,
#     'averageNightly': 132.5,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 1060.0,
#     'tax': None},
#    'priceRanges': [{'currencyUnits': 'USD',
#      'from': 820.0,
#      'periodType': 'WEEKLY',
#      'to': 820.0},
#     {'currencyUnits': 'USD',
#      'from': 3375.0,
#      'periodType': 'MONTHLY',
#      'to': 3375.0},
#     {'currencyUnits': 'USD',
#      'from': 125.0,
#      'periodType': 'NIGHTLY-WEEKDAY',
#      'to': 145.0}],
#    'location': {'lat': 33.837025,
#     'lng': -84.3747979,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 1,
#    'reviewAverage': 5.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=4560074',
#    'bathrooms': 1.0,
#    'bedrooms': 1,
#    'listingUrl': 'https://www.homeaway.com/vacation-rental/p4560074?uni_id=5169329'},
#   {'listingId': 'v682977',
#    'listingSource': 'vrbo',
#    'headline': 'A Warm Chelo Stay minutes to downtown Atlanta',
#    'description': 'We offer a richly decorated, comfortable 1 bedroom, 1 bathroom charming condo minutes from downtown Atlanta, Ga. This condo is located on the first floor for wheelchair accessible if needed with open space, TV, Cable, Internet, DVD, jet tub. The k...',
#    'accommodations': '1 BR, 1.0BA, Sleeps 3',
#    'minStayRange': {'minStayHigh': 2, 'minStayLow': 2},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/b33b2289-726d-40b6-8549-8a78c8d39c6a.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/b33b2289-726d-40b6-8549-8a78c8d39c6a.1.1',
#     'width': 75},
#    'priceQuote': {'amount': 822.0,
#     'averageNightly': 102.75,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 822.0,
#     'tax': None},
#    'priceRanges': [{'currencyUnits': 'USD',
#      'from': 99.0,
#      'periodType': 'NIGHTLY-WEEKDAY',
#      'to': 109.0}],
#    'location': {'lat': 33.70414295,
#     'lng': -84.39725918,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 14,
#    'reviewAverage': 4.5,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=v682977',
#    'bathrooms': 1.0,
#    'bedrooms': 1,
#    'listingUrl': 'https://www.vrbo.com/682977?unitId=1230915'},
#   {'listingId': 'v831953',
#    'listingSource': 'vrbo',
#    'headline': 'Unit 2 - Fully Furnished Beautiful 1 Bedroom Suite',
#    'description': 'Inman Park Place is located in the center of Little Five Points where it offers guests some of the best restaurants and entertainment within walking distance. Inman Park has been voted as one of the most preferred places in Atlanta to work and liv...',
#    'accommodations': '1 BR, 1.0BA, Sleeps 2',
#    'minStayRange': {'minStayHigh': 3, 'minStayLow': 3},
#    'thumbnail': {'height': 101,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/65669225-19ef-4a99-b78b-adff41960758.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/65669225-19ef-4a99-b78b-adff41960758.1.1',
#     'width': 133},
#    'priceQuote': {'amount': 1592.0,
#     'averageNightly': 199.0,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 1592.0,
#     'tax': None},
#    'priceRanges': [{'currencyUnits': 'USD',
#      'from': 199.0,
#      'periodType': 'NIGHTLY-WEEKDAY',
#      'to': 199.0},
#     {'currencyUnits': 'USD',
#      'from': 950.0,
#      'periodType': 'WEEKLY',
#      'to': 950.0},
#     {'currencyUnits': 'USD',
#      'from': 2250.0,
#      'periodType': 'MONTHLY',
#      'to': 2250.0}],
#    'location': {'lat': 33.7644467,
#     'lng': -84.3488902,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 3,
#    'reviewAverage': 5.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=v831953',
#    'bathrooms': 1.0,
#    'bedrooms': 1,
#    'listingUrl': 'https://www.vrbo.com/831953?unitId=1379892'},
#   {'listingId': 'v1240550',
#    'listingSource': 'vrbo',
#    'headline': 'Large Atlanta Super Bowl Home! Safe location, walkable to restaurants & parks!',
#    'description': 'Located in the heart of Buckhead only 10 - 15 minutes from the new Atlanta Battery, Mercedes Benz Stadium (Super Bowl stadium), Phillips Arena, Aquarium, and World of Coke. Walking distance to Publix supermarket, Starbucks, and many great restaura...',
#    'accommodations': '4 BR, 2.0BA, 1HF BA, Sleeps 8',
#    'minStayRange': {'minStayHigh': 3, 'minStayLow': 3},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/dc554f67-14b2-4764-bdca-f8da89313d4d.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/dc554f67-14b2-4764-bdca-f8da89313d4d.1.1',
#     'width': 133},
#    'priceQuote': {'amount': 7600.0,
#     'averageNightly': 950.0,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 7600.0,
#     'tax': None},
#    'priceRanges': [{'currencyUnits': 'USD',
#      'from': 900.0,
#      'periodType': 'NIGHTLY-WEEKDAY',
#      'to': 900.0}],
#    'location': {'lat': 33.8698754,
#     'lng': -84.3779866,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 0,
#    'reviewAverage': 0.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=v1240550',
#    'bathrooms': 2.0,
#    'bedrooms': 4,
#    'listingUrl': 'https://www.vrbo.com/1240550?unitId=1791488'},
#   {'listingId': '3994017',
#    'listingSource': 'homeaway_us',
#    'headline': 'Awesome 2BR price, location & service. Midown/Buckhead for Less Than a Hotel',
#    'description': 'Classic exterior with modern interiors.  All new fixtures and furnishings.  \n\nWe are ideally suited for anyone who is in town for a summer internship, business travel, job re-location, or even just a vacation. This is the most central location in ...',
#    'accommodations': '2 BR, 1.0BA, Sleeps 4',
#    'minStayRange': {'minStayHigh': 3, 'minStayLow': 3},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/94a01198-1294-4340-a0f9-45b6f901339f.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/94a01198-1294-4340-a0f9-45b6f901339f.1.1',
#     'width': 134},
#    'priceQuote': {'amount': 1146.32,
#     'averageNightly': 143.29,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 1146.32,
#     'tax': None},
#    'priceRanges': [{'currencyUnits': 'USD',
#      'from': 161.0,
#      'periodType': 'NIGHTLY-WEEKDAY',
#      'to': 161.0},
#     {'currencyUnits': 'USD',
#      'from': 1003.0,
#      'periodType': 'WEEKLY',
#      'to': 1003.0},
#     {'currencyUnits': 'USD',
#      'from': 3582.0,
#      'periodType': 'MONTHLY',
#      'to': 3582.0}],
#    'location': {'lat': 33.799031,
#     'lng': -84.393644,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 14,
#    'reviewAverage': 4.857143,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=3994017',
#    'bathrooms': 1.0,
#    'bedrooms': 2,
#    'listingUrl': 'https://www.homeaway.com/vacation-rental/p3994017?uni_id=4381863'},
#   {'listingId': '7620215',
#    'listingSource': 'homeaway_us',
#    'headline': 'Midtown Views with dining, shopping and entertainment in walking distance. ',
#    'description': 'Beautiful modern one bedroom condo with great views of the midtown skyline. Parking garage parking is included. Brand new appliances with washer and dryer. Television(no cable) and WiFi is in apartment as well.  Balcony is connected to the bedroom...',
#    'accommodations': '1 BR, 1.0BA, Sleeps 4',
#    'minStayRange': {'minStayHigh': None, 'minStayLow': None},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/4782efb5-9372-4999-8ccf-4882ed416f2d.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/4782efb5-9372-4999-8ccf-4882ed416f2d.1.1',
#     'width': 128},
#    'priceQuote': {'amount': 792.0,
#     'averageNightly': 99.0,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 792.0,
#     'tax': None},
#    'priceRanges': [],
#    'location': {'lat': 33.79182855,
#     'lng': -84.40766138,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 0,
#    'reviewAverage': 0.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=7620215',
#    'bathrooms': 1.0,
#    'bedrooms': 1,
#    'listingUrl': 'https://www.homeaway.com/vacation-rental/p7620215?uni_id=7067759'},
#   {'listingId': '4509119',
#    'listingSource': 'homeaway_us',
#    'headline': 'Downtown Atlanta Loft ',
#    'description': 'Balcony View of the Georgia Dome \n1200 sq ft of open space\nQueen pillow top mattress\nSpacious Living Room\nSafe Parking and Entry\nBalcony View of the Georgia Dome \n1200 sq ft of open space\nQueen pillow top mattress\nSpacious Living Room\nSafe Parking...',
#    'accommodations': '2 BR, 1.0BA, Sleeps 3',
#    'minStayRange': {'minStayHigh': 3, 'minStayLow': 3},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/3ca2e53b-06c9-4855-b05e-2b745b6c2383.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/3ca2e53b-06c9-4855-b05e-2b745b6c2383.1.1',
#     'width': 75},
#    'priceQuote': {'amount': 3600.0,
#     'averageNightly': 450.0,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 3600.0,
#     'tax': None},
#    'priceRanges': [{'currencyUnits': 'USD',
#      'from': 450.0,
#      'periodType': 'NIGHTLY-WEEKDAY',
#      'to': 450.0}],
#    'location': {'lat': 33.75836055,
#     'lng': -84.40396921,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 0,
#    'reviewAverage': 0.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=4509119',
#    'bathrooms': 1.0,
#    'bedrooms': 2,
#    'listingUrl': 'https://www.homeaway.com/vacation-rental/p4509119?uni_id=5112404'},
#   {'listingId': 'v1476847',
#    'listingSource': 'vrbo',
#    'headline': 'Unavailable............',
#    'description': 'Are you looking to enjoy luxury and serenity?\n\nThis apartment offers you free WiFi, a fitness center, pool and a lot more. It is a few minutes walk to Lenox mall and it is ideally situated in Atlanta’s premier shopping and dining district. Our apa...',
#    'accommodations': '1 BR, 1.0BA, Sleeps 3',
#    'minStayRange': {'minStayHigh': None, 'minStayLow': None},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/91d87373-f6e2-4cd2-afdd-af7f8d7d78a8.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/91d87373-f6e2-4cd2-afdd-af7f8d7d78a8.1.1',
#     'width': 134},
#    'priceQuote': {'amount': 1053.0,
#     'averageNightly': 131.63,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 1053.0,
#     'tax': None},
#    'priceRanges': [],
#    'location': {'lat': 33.85376711,
#     'lng': -84.36194987,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 0,
#    'reviewAverage': 0.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=v1476847',
#    'bathrooms': 1.0,
#    'bedrooms': 1,
#    'listingUrl': 'https://www.vrbo.com/1476847?unitId=2035467'},
#   {'listingId': 'v434283',
#    'listingSource': 'vrbo',
#    'headline': 'Charming Midtown Atlanta (Ansley Park) Home',
#    'description': 'Located in the heart of Atlanta in Historic Ansley Park, our home is a most convenient spot from which to access the city. This is our primary residence, not simply a rental house so it is stocked with everything. While many of our belongings rema...',
#    'accommodations': '4 BR, 3.0BA, 1HF BA, Sleeps 6',
#    'minStayRange': {'minStayHigh': 7, 'minStayLow': 7},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/8746011a-14f3-4bcc-abb1-ddb48d9ecb15.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/8746011a-14f3-4bcc-abb1-ddb48d9ecb15.1.1',
#     'width': 133},
#    'priceQuote': {'amount': 3800.0,
#     'averageNightly': 475.0,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 3800.0,
#     'tax': None},
#    'priceRanges': [{'currencyUnits': 'USD',
#      'from': 3325.0,
#      'periodType': 'WEEKLY',
#      'to': 3325.0}],
#    'location': {'lat': 33.7929419,
#     'lng': -84.3813988,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 9,
#    'reviewAverage': 5.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=v434283',
#    'bathrooms': 3.0,
#    'bedrooms': 4,
#    'listingUrl': 'https://www.vrbo.com/434283?unitId=1017333'},
#   {'listingId': 'v432058',
#    'listingSource': 'vrbo',
#    'headline': 'Historic Two-Bedroom Buckhead Bungalow in Heart of Atlanta - S. Buckhead',
#    'description': '1976 Northside Drive NW Atlanta, GA  30318 (near Collier Road)  \n\n$145/night\n$1995/week\n$2151/month\n\nLocated in the historic Buckhead area, known for luxury shopping, beautiful homes, and Southern charm, “The Lustron” is the most unique lodging in...',
#    'accommodations': '2 BR, 1.0BA, Sleeps 4',
#    'minStayRange': {'minStayHigh': 3, 'minStayLow': 3},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/7050fd07-2451-457f-af0b-ec27215fd8d5.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/7050fd07-2451-457f-af0b-ec27215fd8d5.1.1',
#     'width': 121},
#    'priceQuote': {'amount': 1136.8,
#     'averageNightly': 142.1,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 1136.8,
#     'tax': None},
#    'priceRanges': [{'currencyUnits': 'USD',
#      'from': 175.0,
#      'periodType': 'NIGHTLY-WEEKDAY',
#      'to': 175.0},
#     {'currencyUnits': 'USD',
#      'from': 900.0,
#      'periodType': 'WEEKLY',
#      'to': 900.0},
#     {'currencyUnits': 'USD',
#      'from': 2199.9866,
#      'periodType': 'MONTHLY',
#      'to': 2199.9866}],
#    'location': {'lat': 33.809256,
#     'lng': -84.40825,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 20,
#    'reviewAverage': 4.5789475,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=v432058',
#    'bathrooms': 1.0,
#    'bedrooms': 2,
#    'listingUrl': 'https://www.vrbo.com/432058?unitId=1015108'},
#   {'listingId': '7132741',
#    'listingSource': 'homeaway_us',
#    'headline': 'Luxurious Townhouse in the heart of Atlanta',
#    'description': "Right in the middle of everything the city has to offer. Explore the exciting local dining and nightlife. You're in the heart of West Midtown and minutes away from Buckhead and Atlanta’s trendiest neighborhoods of Little Five Points, Old Fourth Wa...",
#    'accommodations': '2 BR, 2.0BA, 1HF BA, Sleeps 15',
#    'minStayRange': {'minStayHigh': 1, 'minStayLow': 1},
#    'thumbnail': {'height': 100,
#     'imageSize': 'SMALL',
#     'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/ba29db7b-d81c-4cb4-8de6-128d31f6c37e.1.1',
#     'uri': 'http://imagesus.homeaway.com/mda01/ba29db7b-d81c-4cb4-8de6-128d31f6c37e.1.1',
#     'width': 134},
#    'priceQuote': {'amount': 4000.0,
#     'averageNightly': 500.0,
#     'currencyUnits': 'USD',
#     'fees': None,
#     'other': None,
#     'rent': 4000.0,
#     'tax': None},
#    'priceRanges': [{'currencyUnits': 'USD',
#      'from': 500.0,
#      'periodType': 'NIGHTLY-WEEKDAY',
#      'to': 500.0}],
#    'location': {'lat': 33.8119091,
#     'lng': -84.42834432,
#     'city': 'Atlanta',
#     'state': 'GA',
#     'country': 'US'},
#    'reviewCount': 0,
#    'reviewAverage': 0.0,
#    'bookWithConfidence': True,
#    'detailsUrl': 'https://ws.homeaway.com/public/listing?id=7132741',
#    'bathrooms': 2.0,
#    'bedrooms': 2,
#    'listingUrl': 'https://www.homeaway.com/vacation-rental/p7132741?uni_id=6279520'}]}

# %%
entries = response['entries']
numEntries = len(response['entries'])

# %%
numEntries
# Out:
# 25

# %%
entries[1]
# Out:
# {'listingId': '7415154',
#  'listingSource': 'homeaway_us',
#  'headline': 'ATL.CV 1414 - Deluxe Apartment One Bedroom 4 pax CV 1414',
#  'description': 'Stake your claim to a life beyond the view. 1stHomeRent connects you to all of the best shopping, dining and activity of Old Fourth Ward, Inman Park and the Atlanta Beltline while allowing you the savings to enjoy them. Our apartment is designed w...',
#  'accommodations': '1 BR, 1.0BA, Sleeps 4',
#  'minStayRange': {'minStayHigh': None, 'minStayLow': None},
#  'thumbnail': {'height': 100,
#   'imageSize': 'SMALL',
#   'secureUri': 'https://imagesus-ssl.homeaway.com/mda01/51711ef9-75ed-4011-89f7-48a27228579d.1.1',
#   'uri': 'http://imagesus.homeaway.com/mda01/51711ef9-75ed-4011-89f7-48a27228579d.1.1',
#   'width': 133},
#  'priceQuote': {'amount': 1726.2,
#   'averageNightly': 215.78,
#   'currencyUnits': 'USD',
#   'fees': None,
#   'other': None,
#   'rent': 1726.2,
#   'tax': None},
#  'priceRanges': [],
#  'location': {'lat': 33.760714,
#   'lng': -84.374001,
#   'city': 'Atlanta',
#   'state': 'GA',
#   'country': 'US'},
#  'reviewCount': 0,
#  'reviewAverage': 0.0,
#  'bookWithConfidence': True,
#  'detailsUrl': 'https://ws.homeaway.com/public/listing?id=7415154',
#  'bathrooms': 1.0,
#  'bedrooms': 1,
#  'listingUrl': 'https://www.homeaway.com/vacation-rental/p7415154?uni_id=6791692'}

# %% [markdown]
# - listingId
# - priceQuote -> amount
# - priceQuote -> averageNightly
# - priceQuote -> fees
# - priceQuote -> rent
# - location -> lat
# - location -> lng
# - location -> city
# - location -> state
# - location -> country
# - reviewCount
# - reviewAverage
# - bathrooms
# - bedrooms
# - listingUrl
# - bookWithConfidence **(maybe??)**

# %% [markdown]
# ### Send GET requests to obtain listings information and extract to DataFrame

# %%
def parseEntry(entries, i):
    tmp_data = pd.DataFrame(
        data=[entries[i]['listingId'],
              entries[i]['priceQuote']['amount'],
              entries[i]['priceQuote']['averageNightly'],
              entries[i]['priceQuote']['fees'],
              entries[i]['priceQuote']['rent'],
              entries[i]['location']['lat'],
              entries[i]['location']['lng'],
              entries[i]['location']['city'],
              entries[i]['location']['state'],
              entries[i]['location']['country'],
              entries[i]['reviewCount'],
              entries[i]['reviewAverage'],
              entries[i]['bathrooms'],
              entries[i]['bedrooms'],
              entries[i]['listingUrl'],
              entries[i]['bookWithConfidence']
             ], 
        index=[
            'listingId',
            'priceAmt',
            'priceAvgNightly',
            'priceFees',
            'priceRent',
            'lat',
            'lng',
            'city',
            'state',
            'country',
            'reviewCount',
            'reviewAverage',
            'bathrooms',
            'bedrooms',
            'listingUrl',
            'bookWithConfidence'
        ]
    ).transpose()
    return(tmp_data)

# %%
# Initialize `data` DataFrame
data = pd.DataFrame(columns=[
        'listingId',
        'priceAmt',
        'priceAvgNightly',
        'priceFees',
        'priceRent',
        'lat',
        'lng',
        'city',
        'state',
        'country',
        'reviewCount',
        'reviewAverage',
        'bathrooms',
        'bedrooms',
        'listingUrl',
        'bookWithConfidence'
    ])

# %%
boolParse = True
i = 0
while(boolParse):
    time.sleep(1)
    i += 1 # increment pageNum counter by 1
    # construct GET request
    url = "https://ws.homeaway.com/public/search"

    val_pageSize = 25
    val_pageNum = i

    date_availabilityStart = "2019-07-01"
    date_availabilityEnd = "2019-07-09"

    querystring = {"q":"Atlanta",
                   "availabilityStart": date_availabilityStart,
                   "availabilityEnd":date_availabilityEnd,
                   "pageSize":str(val_pageSize),
                   "page":str(val_pageNum)}
    

    payload = ""
    headers = {
        'Authorization': "Bearer " + access_token,
        'cache-control': "no-cache",
        'Postman-Token': "9a32c226-9a48-417f-b062-5070f405af71"
        }


    # send GET request
    print("| - - GET - - |")
    print("| - - Sending POST request to", url)
    print("| - - Authorization:", headers['Authorization'])
    print("| - - Postman Token:", headers['Postman-Token'])
    print("| - - - - Query Params - - - - |")
    print("| - - - - - - q:", querystring['q'])
    print("| - - - - - - availabilityStart:", querystring['availabilityStart'])
    print("| - - - - - - availabilityEnd:", querystring['availabilityEnd'])
    print("| - - - - - - pageSize:", querystring['pageSize'])
    print("| - - - - - - page:", querystring['page'])
    response = requests.request("GET", url, data=payload, headers=headers, params=querystring).json()
    print("| - - SUCCESS - - |")
    
    # parse GET response to get entries
    entries = response['entries']
    numEntries = len(response['entries']) # calculate number of entries

    if numEntries > 0:
        # extract pertinent entries into a DataFrame
        print("| - - Parsing pertinent entries - - |")
        for j in range(numEntries):
            data = data.append(parseEntry(entries,j))
            print("| - - - - Row", j, "- - - - |")
    else:
        boolParse = False
        print("| - - COMPLETE - - |")
# Out:
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 1
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 2
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 3
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 4
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 5
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 6
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 7
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 8
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 9
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 10
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 11
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 12
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 13
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 14
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 15
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 16
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 17
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 18
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 19
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 20
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 21
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 22
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 23
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - - - Row 18 - - - - |
# | - - - - Row 19 - - - - |
# | - - - - Row 20 - - - - |
# | - - - - Row 21 - - - - |
# | - - - - Row 22 - - - - |
# | - - - - Row 23 - - - - |
# | - - - - Row 24 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 24
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 25
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - - - Row 16 - - - - |
# | - - - - Row 17 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 26
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 27
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - - - Row 14 - - - - |
# | - - - - Row 15 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 28
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - - - Row 13 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 29
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 30
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 31
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 32
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - - - Row 10 - - - - |
# | - - - - Row 11 - - - - |
# | - - - - Row 12 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 33
# | - - SUCCESS - - |
# | - - Parsing pertinent entries - - |
# | - - - - Row 0 - - - - |
# | - - - - Row 1 - - - - |
# | - - - - Row 2 - - - - |
# | - - - - Row 3 - - - - |
# | - - - - Row 4 - - - - |
# | - - - - Row 5 - - - - |
# | - - - - Row 6 - - - - |
# | - - - - Row 7 - - - - |
# | - - - - Row 8 - - - - |
# | - - - - Row 9 - - - - |
# | - - GET - - |
# | - - Sending POST request to https://ws.homeaway.com/public/search
# | - - Authorization: Bearer OTRhNTRhZWUtN2UwZS00NjU3LThkZTItYTNiMzA0YjYzY2Rj
# | - - Postman Token: 9a32c226-9a48-417f-b062-5070f405af71
# | - - - - Query Params - - - - |
# | - - - - - - q: Atlanta
# | - - - - - - availabilityStart: 2019-07-01
# | - - - - - - availabilityEnd: 2019-07-09
# | - - - - - - pageSize: 25
# | - - - - - - page: 34
# | - - SUCCESS - - |
# | - - COMPLETE - - |

# %%
parseEntry(entries, 1)

# %%
data.shape
# Out:
# (719, 16)

# %%
data
# Out:
#    listingId priceAmt priceAvgNightly priceFees priceRent      lat      lng  \
# 0    7512702     1150          143.75      None      1150  33.7783  -84.391
# 0    7554619     1520             190      None      1520  33.7782 -84.3807
# 0    v625088  3464.76           433.1      None   3464.76  33.7683 -84.3512
# 0   v1424850     1750          218.75      None      1750  33.6701 -84.3831
# 0    7130050      918          114.75      None       918  33.8105 -84.3674
# 0    7172028     1948           243.5      None      1948  33.7733 -84.3868
# 0    v382033     1520             190      None      1520  33.7934 -84.4009
# 0    v468017     1098          137.25      None      1098  33.7874  -84.385
# 0    7263368     1920             240      None      1920  33.7417 -84.3797
# 0   v1376109     1648             206      None      1648  33.7225 -84.4337
# 0   v1417224    602.3           75.29      None     602.3  33.7699 -84.3543
# 0    7290460     1520             190      None      1520   33.761 -84.3738
# 0    7187508     1112             139      None      1112  33.7241 -84.4485
# 0    7331172     1210          151.25      None      1210  33.8488 -84.3666
# 0    v908394      820           102.5      None       820  33.7626 -84.3879
# 0   v1018973     1280             160      None      1280  33.7625 -84.3879
# 0   v1431497      893          111.63      None       893  33.7669 -84.4193
# 0   v1337903   1719.5          214.94      None    1719.5  33.7283  -84.367
# 0    4938297   913.12          114.14      None    913.12  33.7394 -84.3751
# 0    v789728   1101.6           137.7      None    1101.6  33.7767 -84.3521
# 0    7000664     1800             225      None      1800  33.7751 -84.3744
# 0    4023000     1694          211.75      None      1694  33.7574 -84.3694
# 0    4782031     1260           157.5      None      1260  33.7587 -84.3712
# 0    v363870   860.15          107.52      None    860.15  33.7634 -84.3887
# 0    4993538     1800             225      None      1800  33.7751 -84.3744
# 0    4247574  1155.42          144.43      None   1155.42  33.7504 -84.3644
# 0    4467366     1190          148.75      None      1190  33.7682 -84.3604
# 0    v632288     1232             154      None      1232  33.7626 -84.3879
# 0    4777156      936             117      None       936   33.795 -84.3538
# 0    4982430     1775          221.88      None      1775  33.7469 -84.3024
# ..       ...      ...             ...       ...       ...      ...      ...
# 0    7499771      695           86.88      None       695  33.8457 -84.3689
# 0    7363238   3830.4           478.8      None    3830.4    33.83 -84.4314
# 0    7420365   689.04           86.13      None    689.04   33.698 -84.5068
# 0   v1363386  1042.19          130.27      None   1042.19  33.7662 -84.4199
# 0   v1432250    739.5           92.44      None     739.5  33.7098 -84.3968
# 0    7467103      800             100      None       800  33.7285 -84.4023
# 0    7482965  2229.04          278.63      None   2229.04   33.779 -84.3617
# 0    7586410     1032             129      None      1032  33.7637 -84.3915
# 0    7411265     1083          135.38      None      1083   33.811  -84.363
# 0    7565696     1592             199      None      1592  33.7442 -84.4332
# 0   v1533967   839.05          104.88      None    839.05  33.8457 -84.3549
# 0   v1432250    739.5           92.44      None     739.5  33.7098 -84.3968
# 0    7467103      800             100      None       800  33.7285 -84.4023
# 0    7482965  2229.04          278.63      None   2229.04   33.779 -84.3617
# 0   v1428221  1492.45          186.56      None   1492.45  33.7687  -84.414
# 0    7420365   689.04           86.13      None    689.04   33.698 -84.5068
# 0   v1363386  1042.19          130.27      None   1042.19  33.7662 -84.4199
# 0   v1478630     1728             216      None      1728  33.7329  -84.382
# 0    7332509      648              81      None       648  33.7724 -84.3702
# 0    7287988     1520             190      None      1520   33.761 -84.3738
# 0    7333462     1864             233      None      1864  33.7327 -84.4045
# 0    7400048     1818          227.25      None      1818  33.7352 -84.4523
# 0    7162090     4522          565.25      None      4522  33.7804 -84.3783
# 0   v1380627   1432.8           179.1      None    1432.8  33.8892 -84.2767
# 0    7112742      960             120      None       960  33.7724 -84.1847
# 0    7178573     1320             165      None      1320  33.7216 -84.3205
# 0    7301123     4180           522.5      None      4180  33.6578 -84.5603
# 0   v1437224     1395          174.38      None      1395  33.7226 -84.3119
# 0   v1378107   4301.6           537.7      None    4301.6  33.7177 -84.6699
# 0    4895408    877.2          109.65      None     877.2  33.6624 -84.4296
#
#               city state country reviewCount reviewAverage bathrooms bedrooms  \
# 0         Atlanta     GA      US           0             0         1        1
# 0          Atlanta    GA      US           1             5         1        1
# 0          Atlanta    GA      US          19       4.78947         2        4
# 0          Atlanta    GA      US           4          4.75         2        4
# 0          Atlanta    GA      US           5           4.8         1        1
# 0          Atlanta    GA      US          11       4.54545         2        2
# 0          Atlanta    GA      US          18       4.64706         1        1
# 0          Atlanta    GA      US          15       4.42857         1        1
# 0          Atlanta    GA      US           3             4         2        3
# 0          Atlanta    GA      US           2             5         1        3
# 0          Atlanta    GA      US           1             5         1        1
# 0          Atlanta    GA      US           0             0         1        1
# 0          Atlanta    GA      US           1             3         1        3
# 0          Atlanta    GA      US           0             0         1        1
# 0          Atlanta    GA      US           4          2.25         1        1
# 0          Atlanta    GA      US           1             4         1        2
# 0          Atlanta    GA      US           2           2.5         2        3
# 0          Atlanta    GA      US          27       4.88889         2        3
# 0          Atlanta    GA      US           2             4         1        2
# 0          Atlanta    GA      US           4          4.75         1        1
# 0          Atlanta    GA      US          11             5         2        3
# 0          Atlanta    GA      US          25             5         2        3
# 0          Atlanta    GA      US          11       4.72727         1        2
# 0          Atlanta    GA      US         123       4.69919         1        1
# 0          Atlanta    GA      US          10             5         2        2
# 0          Atlanta    GA      US          17       4.88235         1        1
# 0          Atlanta    GA      US           9             5         1        1
# 0          Atlanta    GA      US          73       4.63014         1        1
# 0          Atlanta    GA      US          17             5         1        1
# 0          Atlanta    GA      US           6       4.33333         1        1
# ..             ...   ...     ...         ...           ...       ...      ...
# 0          Atlanta    GA      US           0             0         1        1
# 0          Atlanta    GA      US           3       4.66667         6        7
# 0          Atlanta    GA      US           0             0         1        3
# 0          Atlanta    GA      US           0             0         2        3
# 0          Atlanta    GA      US           0             0         1        2
# 0          Atlanta    GA      US           0             0         1        2
# 0          Atlanta    GA      US           0             0         1        3
# 0          Atlanta    GA      US           0             0         1        1
# 0          Atlanta    GA      US           2             5         1        1
# 0          Atlanta    GA      US           0             0         3        5
# 0          Atlanta    GA      US           0             0         1        1
# 0          Atlanta    GA      US           0             0         1        2
# 0          Atlanta    GA      US           0             0         1        2
# 0          Atlanta    GA      US           0             0         1        3
# 0          Atlanta    GA      US           2           4.5         3        4
# 0          Atlanta    GA      US           0             0         1        3
# 0          Atlanta    GA      US           0             0         2        3
# 0          Atlanta    GA      US           2           4.5         2        3
# 0          Atlanta    GA      US          10           4.6         1        1
# 0          Atlanta    GA      US           0             0         1        1
# 0          Atlanta    GA      US           0             0         2        4
# 0          Atlanta    GA      US           0             0         2        3
# 0          Atlanta    GA      US          10             5         3        4
# 0          Atlanta    GA      US           7             5         2        3
# 0   Stone Mountain    GA      US           5           4.6         2        3
# 0          Atlanta    GA      US           0             0         2        3
# 0          Atlanta    GA      US           0             0         3        6
# 0          Atlanta    GA      US           1             5         2        3
# 0     Douglasville    GA      US           0             0         3        7
# 0       East Point    GA      US           0             0         1        0
#
#                                            listingUrl bookWithConfidence
# 0   https://www.homeaway.com/vacation-rental/p7512...               True
# 0   https://www.homeaway.com/vacation-rental/p7554...               True
# 0          https://www.vrbo.com/625088?unitId=1172869               True
# 0         https://www.vrbo.com/1424850?unitId=1983355               True
# 0   https://www.homeaway.com/vacation-rental/p7130...               True
# 0   https://www.homeaway.com/vacation-rental/p7172...               True
# 0           https://www.vrbo.com/382033?unitId=382033               True
# 0          https://www.vrbo.com/468017?unitId=1051128               True
# 0   https://www.homeaway.com/vacation-rental/p7263...               True
# 0         https://www.vrbo.com/1376109?unitId=1934463               True
# 0         https://www.vrbo.com/1417224?unitId=1975611               True
# 0                                        https://null               True
# 0   https://www.homeaway.com/vacation-rental/p7187...               True
# 0   https://www.homeaway.com/vacation-rental/p7331...               True
# 0          https://www.vrbo.com/908394?unitId=1456335               True
# 0         https://www.vrbo.com/1018973?unitId=1566921               True
# 0         https://www.vrbo.com/1431497?unitId=1990021               True
# 0         https://www.vrbo.com/1337903?unitId=1896239               True
# 0   https://www.homeaway.com/vacation-rental/p4938...               True
# 0          https://www.vrbo.com/789728?unitId=1337666               True
# 0   https://www.homeaway.com/vacation-rental/p7000...               True
# 0   https://www.homeaway.com/vacation-rental/p4023...               True
# 0   https://www.homeaway.com/vacation-rental/p4782...               True
# 0           https://www.vrbo.com/363870?unitId=363870               True
# 0   https://www.homeaway.com/vacation-rental/p4993...               True
# 0   https://www.homeaway.com/vacation-rental/p4247...               True
# 0   https://www.homeaway.com/vacation-rental/p4467...               True
# 0          https://www.vrbo.com/632288?unitId=1180069               True
# 0   https://www.homeaway.com/vacation-rental/p4777...               True
# 0   https://www.homeaway.com/vacation-rental/p4982...               True
# ..                                                ...                ...
# 0   https://www.homeaway.com/vacation-rental/p7499...               True
# 0   https://www.homeaway.com/vacation-rental/p7363...               True
# 0   https://www.homeaway.com/vacation-rental/p7420...               True
# 0         https://www.vrbo.com/1363386?unitId=1921738               True
# 0         https://www.vrbo.com/1432250?unitId=1990774               True
# 0   https://www.homeaway.com/vacation-rental/p7467...               True
# 0   https://www.homeaway.com/vacation-rental/p7482...               True
# 0   https://www.homeaway.com/vacation-rental/p7586...               True
# 0   https://www.homeaway.com/vacation-rental/p7411...               True
# 0   https://www.homeaway.com/vacation-rental/p7565...               True
# 0         https://www.vrbo.com/1533967?unitId=2092772               True
# 0         https://www.vrbo.com/1432250?unitId=1990774               True
# 0   https://www.homeaway.com/vacation-rental/p7467...               True
# 0   https://www.homeaway.com/vacation-rental/p7482...               True
# 0         https://www.vrbo.com/1428221?unitId=1986733               True
# 0   https://www.homeaway.com/vacation-rental/p7420...               True
# 0         https://www.vrbo.com/1363386?unitId=1921738               True
# 0         https://www.vrbo.com/1478630?unitId=2037254               True
# 0   https://www.homeaway.com/vacation-rental/p7332...               True
# 0                                        https://null               True
# 0   https://www.homeaway.com/vacation-rental/p7333...               True
# 0   https://www.homeaway.com/vacation-rental/p7400...               True
# 0   https://www.homeaway.com/vacation-rental/p7162...               True
# 0         https://www.vrbo.com/1380627?unitId=1938985               True
# 0   https://www.homeaway.com/vacation-rental/p7112...               True
# 0   https://www.homeaway.com/vacation-rental/p7178...               True
# 0   https://www.homeaway.com/vacation-rental/p7301...               True
# 0         https://www.vrbo.com/1437224?unitId=1995766               True
# 0         https://www.vrbo.com/1378107?unitId=1936464               True
# 0   https://www.homeaway.com/vacation-rental/p4895...               True
#
# [719 rows x 16 columns]

# %%
# save output dataframe to CSV
data.to_csv("homeaway_data.csv")
